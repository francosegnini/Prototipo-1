# %%
# !pip install speech_recognition
# Out:
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
# !pip install speech_recognition
# Out:
# ERROR: Could not find a version that satisfies the requirement speech_recognition (from versions: none)
# ERROR: No matching distribution found for speech_recognition

# %%
pip install SpeechRecognition
# Out:
# Requirement already satisfied: SpeechRecognition in /root/venv/lib/python3.10/site-packages (3.14.3)
# Requirement already satisfied: typing-extensions in /root/venv/lib/python3.10/site-packages (from SpeechRecognition) (4.13.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /root/venv/lib/python3.10/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /root/venv/lib/python3.10/site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# prototipo_app.py
import streamlit as st
import pandas as pd
import pytesseract
import speech_recognition as sr
from PIL import Image
from datetime import datetime
import os
import sqlite3

# Conexión a base de datos local SQLite
DB_FILE = "procedimientos.db"
conn = sqlite3.connect(DB_FILE, check_same_thread=False)
c = conn.cursor()

# Crear tabla si no existe
c.execute('''
    CREATE TABLE IF NOT EXISTS procedimientos (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        timestamp TEXT,
        nombre_paciente TEXT,
        documento TEXT,
        fecha_nacimiento TEXT,
        anio_residencia TEXT,
        hospital TEXT,
        rol_residente TEXT,
        instructor TEXT,
        procedimiento_codigo TEXT,
        procedimiento_nombre TEXT,
        metodo_registro TEXT
    )
''')
conn.commit()

# Archivo Excel de códigos
codigo_excel = "codigos_procedimientos.xlsx"

@st.cache_data
def cargar_tabla_codigos():
    df = pd.read_excel(codigo_excel)
    if "Codigo" not in df.columns or "Nombre" not in df.columns or "Habilitado" not in df.columns:
        st.error("El archivo de procedimientos debe contener las columnas 'Codigo', 'Nombre' y 'Habilitado'.")
        st.stop()
    return df[df["Habilitado"] == "SI"]

codigos_df = cargar_tabla_codigos()

st.title("🧠 Registro Inteligente de Procedimientos Médicos")

modo = st.radio("Selecciona el modo de registro", ["📷 Imagen", "🎙️ Audio"])
registro = {
    "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
    "metodo_registro": modo
}

if modo == "📷 Imagen":
    imagen = st.file_uploader("Sube o toma una foto del documento del paciente", type=["jpg", "jpeg", "png"])
    if imagen:
        img = Image.open(imagen)
        st.image(img, caption="Imagen cargada", use_column_width=True)

        texto_extraido = pytesseract.image_to_string(img, lang='spa')
        texto_area = st.text_area("Texto detectado (editable)", value=texto_extraido, height=200)

        registro["nombre_paciente"] = next((line.split(":")[-1].strip() for line in texto_area.splitlines() if "nombre" in line.lower()), "")
        registro["documento"] = next((line.split(":")[-1].strip() for line in texto_area.splitlines() if "documento" in line.lower()), "")
        registro["fecha_nacimiento"] = next((line.split(":")[-1].strip() for line in texto_area.splitlines() if "nacimiento" in line.lower() or "edad" in line.lower()), "")

elif modo == "🎙️ Audio":
    st.info("Usa una grabación de voz clara donde menciones los campos uno a uno")
    audio_file = st.file_uploader("Sube una grabación de audio", type=["wav", "mp3"])

    if audio_file:
        recognizer = sr.Recognizer()
        with sr.AudioFile(audio_file) as source:
            audio_data = recognizer.record(source)
            try:
                texto = recognizer.recognize_google(audio_data, language="es-ES")
                texto_area = st.text_area("Texto reconocido (editable)", value=texto, height=150)

                registro["nombre_paciente"] = next((seg.strip() for seg in texto_area.split(" ") if "paciente" in seg.lower()), "")
                registro["documento"] = next((seg.strip() for seg in texto_area.split(" ") if seg.isdigit()), "")
                registro["fecha_nacimiento"] = ""

            except sr.UnknownValueError:
                st.error("No se pudo entender el audio")

st.subheader("📝 Datos del procedimiento")
registro["anio_residencia"] = st.selectbox("Año de residencia", ["1", "2", "3", "4", "5"])
registro["hospital"] = st.text_input("Hospital")
registro["rol_residente"] = st.selectbox("Rol", ["Cirujano Principal", "Ayudante 1", "Ayudante 2"])
registro["instructor"] = st.text_input("Instructor responsable")

codigo_sel = st.selectbox("Procedimiento realizado", codigos_df["Nombre"].sort_values())
registro["procedimiento_nombre"] = codigo_sel
registro["procedimiento_codigo"] = codigos_df[codigos_df["Nombre"] == codigo_sel]["Codigo"].values[0]

if st.button("Registrar procedimiento"):
    valores = [
        registro["timestamp"], registro.get("nombre_paciente", ""), registro.get("documento", ""),
        registro.get("fecha_nacimiento", ""), registro["anio_residencia"], registro["hospital"],
        registro["rol_residente"], registro["instructor"],
        registro["procedimiento_codigo"], registro["procedimiento_nombre"], registro["metodo_registro"]
    ]
    c.execute('''INSERT INTO procedimientos (
        timestamp, nombre_paciente, documento, fecha_nacimiento, anio_residencia,
        hospital, rol_residente, instructor, procedimiento_codigo, procedimiento_nombre,
        metodo_registro
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''', valores)
    conn.commit()
    st.success("✅ Procedimiento registrado exitosamente")

    df = pd.read_sql_query("SELECT * FROM procedimientos ORDER BY id DESC LIMIT 1", conn)
    st.dataframe(df)

    # Exportar a Excel automáticamente
    df_total = pd.read_sql_query("SELECT * FROM procedimientos ORDER BY id DESC", conn)
    excel_output = "procedimientos_exportados.xlsx"
    df_total.to_excel(excel_output, index=False)
    st.info(f"📁 Archivo actualizado: {excel_output}")
    with open(excel_output, "rb") as f:
        st.download_button("📤 Descargar Excel actualizado", f, file_name=excel_output, mime="application/vnd.openxmlformats-officedocument.spreadsheetml.sheet")
# Out:
# 2025-05-16 22:32:39.710 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-05-16 22:32:39.712 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-05-16 22:32:39.713 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:39.950
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-05-16 22:32:39.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:39.952 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:40.461 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:40.478 Thread 'Thread-5': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.294 Session state does not function when running a script without `streamlit run`
# 2025-05-16 22:32:41.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.332 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-16 22:32:41.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7bbee2e6-04d8-494a-90a6-2d1c1072e700' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
